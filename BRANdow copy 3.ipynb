# %%
import os
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt 
import xarray as xr
import pandas as pd
import datetime

def wr(txt):
    w=open('日志4.log','a')
    w.write(txt)
    w.close()

http_proxy = "socks://127.0.0.1:20808"
https_proxy = "socks://127.0.0.1:20808"
os.environ['HTTP_PROXY'] = http_proxy
os.environ['HTTPS_PROXY'] = https_proxy

# x 1499:1:2499
# y 949:1:1399
# z 0:1:33

# %%
t=pd.date_range('19930101','20221231',freq='M')
ts=pd.date_range('19930101','20221231',freq='D')
per=[
    [0,16],
    [16,33]
]
num=334
nums=num
wr(f'{datetime.datetime.now()}: Start Download : \n')
for i in t[num:360]:
    ml=ts[(ts.year==i.year)&(ts.month==i.month)].shape[0]-1
    
    # wr(f'{datetime.datetime.now()}:   MLD Download : ocean_mld_{i.year}_{i.month:02d}.nc \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_mld_{i.year}_{i.month:02d}.nc?mld[0:1:{ml}][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\mld\ocean_mld_{i.year}_{i.month:02d}.nc')
    # wr(rf'{datetime.datetime.now()}:   MLD Down End : Save To E:\OceanData\Bran\mld\ocean_mld_{i.year}_{i.month:02d}.nc')
    # wr('\n')
    
    wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_temp_{i.year}_{i.month:02d}.npy \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\temp\ocean_temp_{i.year}_{i.month:02d}.nc')
    temp=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['temp']) for j in per],axis=1))
    np.save(rf'E:\OceanData\Bran\temp\ocean_temp_{i.year}_{i.month:02d}.npy',temp)
    wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\temp\ocean_temp_{i.year}_{i.month:02d}.npy')
    wr('\n')
    
    wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_u_{i.year}_{i.month:02d}.npy \n')
    #das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    #das.to_netcdf(rf'E:\OceanData\Bran\u\ocean_u_{i.year}_{i.month:02d}.nc')
    us=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['u']) for j in per],axis=1))
    np.save(rf'E:\OceanData\Bran\u\ocean_u_{i.year}_{i.month:02d}.npy',us)
    wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\u\ocean_u_{i.year}_{i.month:02d}.npy')
    wr('\n')
    
    wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_v_{i.year}_{i.month:02d}.npy \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\v\ocean_v_{i.year}_{i.month:02d}.nc')
    vs=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['v']) for j in per],axis=1))
    np.save(rf'E:\OceanData\Bran\v\ocean_v_{i.year}_{i.month:02d}.npy',vs)
    wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\v\ocean_v_{i.year}_{i.month:02d}.npy')
    wr('\n')
    nums+=1
    wr(str(nums))

# %%
t=pd.date_range('19930101','20221231',freq='M')
ts=pd.date_range('19930101','20221231',freq='D')
numss=[
    [35,100],
    [132,200],
    [234,300],
    [334,360]
]
ns=np.concatenate([np.arange(i[0],i[1],1)  for i in numss])
t[ns]

# %%
for j in range(10):
    w=open(f'DOW{j:02d}.sh','w')
    #w.write('cd E:\OceanData\Bran \n')
    for i in t[ns[j*10:j*10+10]]:
        ml=ts[(ts.year==i.year)&(ts.month==i.month)].shape[0]-1
        w.write(f'echo "$(date): Starting  ocean_temp_{i.year}_{i.month:02d}_1.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/temp/ocean_temp_{i.year}_{i.month:02d}_1.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_temp_{i.year}_{i.month:02d}_2.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/temp/ocean_temp_{i.year}_{i.month:02d}_2.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_temp_{i.year}_{i.month:02d}_3.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/temp/ocean_temp_{i.year}_{i.month:02d}_3.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_u_{i.year}_{i.month:02d}_1.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{i.year}_{i.month:02d}_1.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_u_{i.year}_{i.month:02d}_2.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{i.year}_{i.month:02d}_2.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_u_{i.year}_{i.month:02d}_3.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{i.year}_{i.month:02d}_3.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_v_{i.year}_{i.month:02d}_1.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v/ocean_v_{i.year}_{i.month:02d}_1.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_v_{i.year}_{i.month:02d}_2.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v/ocean_v_{i.year}_{i.month:02d}_2.nc')
        
        w.write(f'\necho "$(date): Starting  ocean_v_{i.year}_{i.month:02d}_3.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v/ocean_v_{i.year}_{i.month:02d}_3.nc')
        w.write('\n')
    w.close()

# %%
w1=open(f'temp.txt','w')
w2=open(f'u.txt','w')
w3=open(f'v.txt','w')
# w.write('cd E:\OceanData\Bran \n')
for i in t[ns]:
    ml=ts[(ts.year==i.year)&(ts.month==i.month)].shape[0]-1
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499] ./temp/ocean_temp_{i.year}_{i.month:02d}_1.nc')
    # w.write('\n')
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][16:1:33][949:1:1399][1499:1:2499] ./temp/ocean_temp_{i.year}_{i.month:02d}_2.nc')
    # w.write('\n')
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499] ./u/ocean_u_{i.year}_{i.month:02d}_1.nc')
    # w.write('\n')
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][16:1:33][949:1:1399][1499:1:2499] ./u/ocean_u_{i.year}_{i.month:02d}_2.nc')
    # w.write('\n')
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499] ./v/ocean_v_{i.year}_{i.month:02d}_1.nc')
    # w.write('\n')
    # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][33:1:33][949:1:1399][1499:1:2499] ./v/ocean_v_{i.year}_{i.month:02d}_2.nc')
    # w.write('\n')
    w1.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499] \n")
    w1.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.year}_{i.month:02d}.nc?temp[0:1:{ml}][16:1:33][949:1:1399][1499:1:2499] \n")
    
    w2.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499]")
    w2.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.year}_{i.month:02d}.nc?u[0:1:{ml}][16:1:33][949:1:1399][1499:1:2499]")
    
    w3.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][0:1:16][949:1:1399][1499:1:2499]")
    w3.write(f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.year}_{i.month:02d}.nc?v[0:1:{ml}][33:1:33][949:1:1399][1499:1:2499]")
w1.close()
w2.close()
w3.close()

# %%
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_mld_2020_11.nc?mld[0:1:29][949:1:1399][1499:1:2499] test.nc

# %% [markdown]
# -P 4：并行处理，使用4个线程进行下载。
# -f nc4c：指定输出文件格式。
# --no-copy：禁止使用内存缓存。
# -r：强制使用远程服务器计算。
# -L：启用断点续传，确保可以在中断时从中继续下载。
# -O：覆盖任何现有的输出文件。
# -s：遇到错误时停止CDO。
# -v var1,var2：指定要下载的变量列表。
# -z zip_1M：采用1MB的zip压缩包，以提高下载速度。
# -y era：指定数据集的类型。

# %%
import paramiko
import os
import pandas as pd
import numpy as np
# SSH 连接信息
hostname = "10.130.2.222"
username = "yuhanxue"
password = "xmzx181yf#"

# 创建 SSH 客户端
client = paramiko.SSHClient()
client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
client.connect(hostname=hostname, username=username, password=password)

# 创建 SFTP 客户端
sftp = client.open_sftp()
temps_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/temp")
u_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/u")
v_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/v")

# 本地文件
temps_loc = os.listdir(r'F:\OceanData\Bran\temp')
u_loc = os.listdir(r'F:\OceanData\Bran\u')
v_loc = os.listdir(r'F:\OceanData\Bran\v')
sftp.close()
client.close()

# %%
t=pd.date_range('19930101','20221231',freq='M')
ts=pd.date_range('19930101','20221231',freq='D')
all=[]
for i in t:
    all.append([str(i.year),f'{i.month:02d}','1'])
    all.append([str(i.year),f'{i.month:02d}','2'])
    all.append([str(i.year),f'{i.month:02d}','3'])
    
def justncnpy(s):
    allows=['npy','nc','NPY','NC']
    if s.split('.')[-1] in allows:
        return True
    else:
        return False      
def getda(s):
    ks=s.split('.')[0].split('_')[2:]
    if len(ks)==2:
        a1=s.split('.')[0].split('_')[2:];a1.append('1')
        a2=s.split('.')[0].split('_')[2:];a2.append('2')
        a3=s.split('.')[0].split('_')[2:];a3.append('3')
        return a1,a2,a3
    elif len(ks)==3:
        return ks
def sets(s):
    a=''
    for i in s:
        a+=i
        a+='_'
    return a[:-1]
def setss(li):
    k=list(map(sets,li))
    k.sort()
    return set(k)
    
temps=[];temps.extend(temps_loc);temps.extend(temps_ssh)
temps=np.unique(np.array(temps)[list(map(justncnpy,temps))])


us=[];us.extend(u_loc);us.extend(u_ssh)
us=np.unique(np.array(us)[list(map(justncnpy,us))])

vs=[];vs.extend(v_loc);vs.extend(v_ssh)
vs=np.unique(np.array(vs)[list(map(justncnpy,vs))])


tmp=[]
for i in list(map(getda,temps)):
    if type(i)==tuple:
        #tmp.append(i[0]);tmp.append(i[1]);tmp.append(i[2])
        pass
    else:
        tmp.append(i)
temps=tmp

tmp=[]
for i in list(map(getda,us)):
    if type(i)==tuple:
        tmp.append(i[0]);tmp.append(i[1]);tmp.append(i[2])
    else:
        tmp.append(i)
us=tmp

tmp=[]
for i in list(map(getda,vs)):
    if type(i)==tuple:
        tmp.append(i[0]);tmp.append(i[1]);tmp.append(i[2])
    else:
        tmp.append(i)
vs=tmp

temp_add=list(setss(all) - setss(temps))
u_add=list(setss(all) - setss(us))
v_add=list(setss(all) - setss(vs))
temp_add.sort()
u_add.sort()
v_add.sort()

# %%
def tempw(li):
    sep=len(li)//5
    for j in range(5):
        w=open(f'DOW{j:02d}.sh','w',newline='\n')
        for i in li[j*sep:j*sep+sep]:
            lis=i.split('_')
            ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
            w.write(f'\necho "$(date): Starting  ocean_temp_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
            w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{lis[0]}_{int(lis[1]):02d}.nc?temp[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/temp/ocean_temp_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
            #print(ml)
        w.close()
    w=open(f'DOW{j+1:02d}.sh','w',newline='\n')
    for i in li[j*sep+sep:]:
        lis=i.split('_')
        ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
        w.write(f'\necho "$(date): Starting  ocean_temp_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{lis[0]}_{int(lis[1]):02d}.nc?temp[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/temp/ocean_temp_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
        #print(ml)
    w.close()
def uw(li):
    sep=len(li)//5
    for j in range(5):
        w=open(f'DOW{j:02d}.sh','a',newline='\n')
        for i in li[j*sep:j*sep+sep]:
            lis=i.split('_')
            ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
            w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
            w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
            #print(ml)
        w.close()
    w=open(f'DOW{j+1:02d}.sh','a',newline='\n')
    for i in li[j*sep+sep:]:
        lis=i.split('_')
        ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
        w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
        #print(ml)
    w.close()    
def vw(li):
    sep=len(li)//5
    for j in range(5):
        w=open(f'DOW{j:02d}.sh','a',newline='\n')
        for i in li[j*sep:j*sep+sep]:
            lis=i.split('_')
            ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
            w.write(f'\necho "$(date): Starting  ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
            w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{lis[0]}_{int(lis[1]):02d}.nc?v[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v/ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
            #print(ml)
        w.close()
    w=open(f'DOW{j+1:02d}.sh','a',newline='\n')
    for i in li[j*sep+sep:]:
        lis=i.split('_')
        ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
        w.write(f'\necho "$(date): Starting  ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v/ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
        #print(ml)
    w.close()       

tempw(temp_add)
uw(u_add)
vw(v_add)

# %%
t=pd.date_range('19930101','20221231',freq='M')
ts=pd.date_range('19930101','20221231',freq='D')


def uw(li):
    sep=len(li)//5
    for j in range(5):
        w=open(f'DOW{j:02d}.sh','w',newline='\n')
        for i in li[j*sep:j*sep+sep]:
            lis=i.split('_')
            ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
            # w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_1.nc" \n')
            # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{lis[0]}_{int(lis[1]):02d}_1.nc')
            w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_2.nc" \n')
            w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u2/ocean_u_{lis[0]}_{int(lis[1]):02d}_2.nc')
            w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_3.nc" \n')
            w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u2/ocean_u_{lis[0]}_{int(lis[1]):02d}_3.nc')
            #print(ml)
        w.close()
    w=open(f'DOW{j+1:02d}.sh','w',newline='\n')
    for i in li[j*sep+sep:]:
        lis=i.split('_')
        ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
        # w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_1.nc" \n')
        # w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][0:1:11][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u/ocean_u_{lis[0]}_{int(lis[1]):02d}_1.nc')
        w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_2.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u2/ocean_u_{lis[0]}_{int(lis[1]):02d}_2.nc')
        w.write(f'\necho "$(date): Starting  ocean_u_{lis[0]}_{int(lis[1]):02d}_3.nc" \n')
        w.write(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{lis[0]}_{int(lis[1]):02d}.nc?u[0:1:{ml}][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/u2/ocean_u_{lis[0]}_{int(lis[1]):02d}_3.nc')
        
        #print(ml)
    w.close()    

uw(temp_add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 t=pd.date_range('19930101','20221231',freq='M')
#       2 ts=pd.date_range('19930101','20221231',freq='D')
#       5 def uw(li):
#
# NameError: name 'pd' is not defined

# %%
import os
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt 
import xarray as xr
import pandas as pd
import datetime

def wr(txt):
    w=open('日志4.log','a')
    w.write(txt)
    w.close()

http_proxy = "socks://127.0.0.1:20808"
https_proxy = "socks://127.0.0.1:20808"
os.environ['HTTP_PROXY'] = http_proxy
os.environ['HTTPS_PROXY'] = https_proxy

# %%
with open(r'D:\OneDrive\heat_budget\MHW_HB\need3.txt','r') as f:
    a=f.readlines()
def getdat(s):
    return s.split()[0].split("'")[1][:7].replace('-','_')
temp_add = np.unique(np.array(sorted(map(getdat,a))))
print(temp_add)
# Out:
# ['1994_04' '1996_02' '1996_10' '1996_12' '1997_06' '1997_08' '1997_09'
#  '1998_02' '1998_04' '1998_06' '1999_02' '2000_02' '2000_04' '2000_05'
#  '2000_12' '2001_02' '2003_03' '2004_02' '2004_06' '2004_11' '2005_02'
#  '2005_04' '2005_11' '2006_02' '2008_01' '2008_03' '2008_06' '2013_03'
#  '2014_02' '2014_05' '2015_05' '2016_03' '2016_05' '2016_11' '2017_01'
#  '2017_05' '2017_07' '2021_01' '2021_03' '2021_07' '2021_09' '2021_12'
#  '2022_10' '2022_12']

# %%
def r2(s):
    return s[:-2]
wr(f'{datetime.datetime.now()}: Start Download : \n')
per=[
    [0,11],
    [11,22],
    [22,33]
]
ts=pd.date_range('19930101','20221231',freq='D')
num=38
print(temp_add)
for i in temp_add[num:]:
    print(temp_add[num])
    ml=ts[(ts.year==int(i.split("_")[0]))&(ts.month==int(i.split("_")[1]))].shape[0]-1
    
    # wr(f'{datetime.datetime.now()}:   MLD Download : ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?mld[0:1:{ml}][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr(rf'{datetime.datetime.now()}:   MLD Down End : Save To E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr('\n')
    
    wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    temp=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['temp']) for j in per],axis=1))
    np.save(rf'F:\OceanData\Bran\temp3\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',temp)
    wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\temp3\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  U Download : ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # #das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # #das.to_netcdf(rf'E:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # us=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['u']) for j in per],axis=1))
    # np.save(rf'F:\OceanData\Bran\u3\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',us)
    # wr(rf'{datetime.datetime.now()}:  U Down End : Save To E:\OceanData\Bran\u3\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # # das.to_netcdf(rf'E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # vs=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['v']) for j in per],axis=1))
    # np.save(rf'E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',vs)
    # wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    print(num)
    num+=1
# Out:
# ['1994_04' '1996_02' '1996_10' '1996_12' '1997_06' '1997_08' '1997_09'
#  '1998_02' '1998_04' '1998_06' '1999_02' '2000_02' '2000_04' '2000_05'
#  '2000_12' '2001_02' '2003_03' '2004_02' '2004_06' '2004_11' '2005_02'
#  '2005_04' '2005_11' '2006_02' '2008_01' '2008_03' '2008_06' '2013_03'
#  '2014_02' '2014_05' '2015_05' '2016_03' '2016_05' '2016_11' '2017_01'
#  '2017_05' '2017_07' '2021_01' '2021_03' '2021_07' '2021_09' '2021_12'
#  '2022_10' '2022_12']
# 2021_03
# 38
# 2021_07
# 39
# 2021_09
# 40
# 2021_12
# 41
# 2022_10
# 42
# 2022_12
# 43

# %%
def r2(s):
    return s[:-2]
wr(f'{datetime.datetime.now()}: Start Download : \n')
per=[
    [0,11],
    [11,22],
    [22,33]
]
ts=pd.date_range('19930101','20221231',freq='D')
num=0
print(list(map(str,np.unique(list(map(r2,u_add))))))
for i in list(map(str,np.unique(list(map(r2,u_add)))))[num:]:
    print(list(map(str,np.unique(list(map(r2,u_add)))))[num])
    ml=ts[(ts.year==int(i.split("_")[0]))&(ts.month==int(i.split("_")[1]))].shape[0]-1
    
    # wr(f'{datetime.datetime.now()}:   MLD Download : ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?mld[0:1:{ml}][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr(rf'{datetime.datetime.now()}:   MLD Down End : Save To E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # # das.to_netcdf(rf'E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # temp=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['temp']) for j in per],axis=1))
    # np.save(rf'E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',temp)
    # wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    
    wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    #das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    #das.to_netcdf(rf'E:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    us=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['u']) for j in per],axis=1))
    np.save(rf'F:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',us)
    wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # # das.to_netcdf(rf'E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # vs=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['v']) for j in per],axis=1))
    # np.save(rf'E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',vs)
    # wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    print(num)
    num+=1

# %%
def r2(s):
    return s[:-2]
wr(f'{datetime.datetime.now()}: Start Download : \n')
per=[
    [0,11],
    [11,22],
    [22,33]
]
ts=pd.date_range('19930101','20221231',freq='D')
num=10
print(list(map(str,np.unique(list(map(r2,v_add))))))
for i in list(map(str,np.unique(list(map(r2,v_add)))))[num:]:
    print(num)
    ml=ts[(ts.year==int(i.split("_")[0]))&(ts.month==int(i.split("_")[1]))].shape[0]-1
    
    # wr(f'{datetime.datetime.now()}:   MLD Download : ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?mld[0:1:{ml}][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr(rf'{datetime.datetime.now()}:   MLD Down End : Save To E:\OceanData\Bran\mld\ocean_mld_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # # das.to_netcdf(rf'E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # temp=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?temp[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['temp']) for j in per],axis=1))
    # np.save(rf'E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',temp)
    # wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\temp\ocean_temp_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    
    # wr(f'{datetime.datetime.now()}:  TEMP Download : ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # #das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # #das.to_netcdf(rf'E:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    # us=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?u[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['u']) for j in per],axis=1))
    # np.save(rf'F:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',us)
    # wr(rf'{datetime.datetime.now()}:  TEMP Down End : Save To E:\OceanData\Bran\u\ocean_u_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    # wr('\n')
    
    wr(f'{datetime.datetime.now()}:  V Download : ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy \n')
    # das=xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][0:1:33][949:1:1399][1499:1:2499]')
    # das.to_netcdf(rf'E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc')
    vs=np.array(np.concatenate([np.array(xr.open_dataset(f'https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.nc?v[0:1:{ml}][{j[0]}:1:{j[1]}][949:1:1399][1499:1:2499]')['v']) for j in per],axis=1))
    np.save(rf'F:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy',vs)
    wr(rf'{datetime.datetime.now()}:  V Down End : Save To E:\OceanData\Bran\v\ocean_v_{i.split("_")[0]}_{int(i.split("_")[1]):02d}.npy')
    wr('\n')
    print(num)
    num+=1

# %%
import paramiko
import os
import pandas as pd
import numpy as np
# SSH 连接信息
hostname = "10.130.2.222"
username = "yuhanxue"
password = "xmzx181yf#"

# 创建 SSH 客户端
client = paramiko.SSHClient()
client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
client.connect(hostname=hostname, username=username, password=password)

# 创建 SFTP 客户端
sftp = client.open_sftp()
#temps_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/temp")
u_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/u2")
v_ssh=sftp.listdir("/lustre/home/yuhanxue/data/BRAN/v2")

# %%
def getn(st):
    return st.split('.')[0][8:]
u_ssh=list(map(getn,u_ssh))
u_ssh.sort()
f=open(r'D:\OneDrive\heat_budget\MHW_HB\needs.txt','r')
a=f.readlines()
f.close()
def getdat(s):
    return s.split('.')[0].split('_')[-3]+'_'+s.split('.')[0].split('_')[-2]
u_add=list(map(getdat,a))
def getn2(st):
    return [st+'_2',st+'_3']
a=list(map(getn2,u_add))
u_add=[]
for i in a:
    u_add.extend(i)
u_add.sort()
set(u_add)-set(u_ssh)
# Out:
# set()

# %%
def getn(st):
    return st.split('.')[0][8:]
v_ssh=list(map(getn,v_ssh))
v_ssh.sort()
f=open(r'D:\OneDrive\heat_budget\MHW_HB\needs2.txt','r')
a=f.readlines()
f.close()
def getdat(s):
    return s.split('.')[0].split('_')[-3]+'_'+s.split('.')[0].split('_')[-2]
v_add=list(map(getdat,a))
def getn2(st):
    return [st+'_2',st+'_3']
a=list(map(getn2,v_add))
v_add=[]
for i in a:
    v_add.extend(i)
v_add.sort()
set(v_add)-set(v_ssh)
# Out:
# set()

# %%
t=pd.date_range('19930101','20221231',freq='M')
ts=pd.date_range('19930101','20221231',freq='D')
per=[
    [0,11],
    [11,22],
    [22,33]
]
def vw(li):
    for i in li:
        lis=i.split('_')
        ml=ts[(ts.year==int(lis[0]))&(ts.month==int(lis[1]))].shape[0]-1
        # print(f'\necho "$(date): Starting  ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc" \n')
        print(f'ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_{lis[0]}_{int(lis[1]):02d}.nc?v[0:1:{ml}][{per[int(lis[-1])-1][0]}:1:{per[int(lis[-1])-1][1]}][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_{lis[0]}_{int(lis[1]):02d}_{lis[-1]}.nc')
            #print(ml)
    #w=open(f'DOW{j+1:02d}.sh','a',newline='\n')
vw(list(set(v_add)-set(v_ssh)))
# Out:
# ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2021_08.nc?v[0:1:30][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2021_08_2.nc
# ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2013_03.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2013_03_3.nc
# ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2014_05.nc?v[0:1:30][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2014_05_2.nc
# ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2017_03.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2017_03_3.nc
# ...

# %%
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2021_08.nc?v[0:1:30][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2021_08_2.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2013_03.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2013_03_3.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2014_05.nc?v[0:1:30][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2014_05_2.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2017_03.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2017_03_3.nc

# %%
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2014_05.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2014_05_3.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2004_05.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2004_05_3.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2016_03.nc?v[0:1:30][11:1:22][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2016_03_2.nc
ncks -O -4 -L 8 -P -s 4M https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_v_2016_03.nc?v[0:1:30][22:1:33][949:1:1399][1499:1:2499] /lustre/home/yuhanxue/data/BRAN/v2/ocean_v_2016_03_3.nc
