# %%
import pandas as pd
import netCDF4 as nc
import numpy as np
import xarray as xr
f=open('data_need.txt','r')
a=f.readlines()
f.close()

lis=[]
for i in a:
    lis.extend(i.split())
lis2=[]
for i in lis:
    lis2.append(i.split('T')[0][1:])

time=pd.to_datetime(lis2)

# %%
gettemp(time)
# Out:
# "https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_Index([2005], dtype='int32')_Index([10], dtype='int32').nc?temp[Index([0], dtype='int32'):1:Index([0], dtype='int32')][0:1:33][949:1:1399][1499:1:2499]"

# %%
time_test=pd.to_datetime('2005-10-01')
def gettemp(t):
    return f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{t.year}_{str(t.month):>02s}.nc?temp[{t.day-1}:1:{t.day-1}][0:1:33][949:1:1399][1499:1:2499]"
print(gettemp(time_test))
def dow(t):
    dat= np.array(nc.Dataset(gettemp(t))['temp'])
    np.save(f'ocean_temp_{t.year}_{t.month}_{t.day}.npy',dat)
#list(map(dow,time))
# dat= np.array(nc.Dataset(gettemp(time_test))['temp'])
dow(time_test)
# Out:
# https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_2005_10.nc?temp[0:1:0][0:1:33][949:1:1399][1499:1:2499]

# %%
dat[dat<-1000]=np.nan
np.nanmean(dat)
# Out:
# 12.528045

# %%
time_test=pd.to_datetime('1995-08-20')
def gettemp(t):
    return f"https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_{t.year}_{str(t.month):>02s}.nc?temp[{t.day-1}:1:{t.day-1}][0:1:33][949:1:1399][1499:1:2499]"
print(gettemp(time_test))
def dow(t):
    dat= np.array(nc.Dataset(gettemp(t))['temp'])
    np.save(f'ocean_temp_{t.year}_{t.month}_{t.day}.npy',dat)
list(map(dow,time))
# Out:
# https://dapds00.nci.org.au/thredds/dodsC/gb6/BRAN/BRAN2020/daily/ocean_temp_1995_08.nc?temp[19:1:19][0:1:33][949:1:1399][1499:1:2499]
# [None, None, None]
