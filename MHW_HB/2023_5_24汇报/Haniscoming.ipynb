# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=np.load("20230525HeatBudget&HeatWave.npz")
mltt=np.array(data['mltt'])
Q=np.array(data['Q'])
hadv=np.array(data['hadv'])
mltt=mltt[:,:-1,:-1]
Q=Q[1:,:-1,:-1]
hadv=hadv[1:,:,:]

# %%
times=pd.date_range('1993-01-01','2022-12-31',freq='1D')
times=times[1:]
lon=np.arange(150,250,0.25)
lat=np.arange(20,60,0.25)
latind=(lat>=35)&(lat<=50)
lonind=(lon>=165)&(lon<=230)

# %%
def yermon(date):
    year = np.array(date.year,dtype=float)
    month = np.array(date.month,dtype=float)
    month[month<6]=0.
    month[month>=6]=0.5
    return(month+year)
def yearis(dat):
    elyear=[1951.5, 1952.0,1953.5, 1954.0,1957.5, 1958.0,1958.5, 1959.0,1963.5, 
            1964.0,1965.5, 1966.0,1968.5, 1969.0,1969.5, 1970.0,1972.5, 1973.0,
            1976.5, 1977.0,1977.5, 1978.0,1979.5, 1980.0,1982.5, 1983.0,1986.5, 
            1987.0,1987.5, 1988.0,1991.5, 1992.0,1994.5, 1995.0,1997.5,1998.0,
            2002.5,2003.0,2004.5,2005.0,2006.5,2007.0,2009.5,2010.0,2014.5,2015.0,
            2015.5,2016.0,2018.5,2019.0]
    layear=[1954.5, 1955.0,1955.5, 1956.0,1964.5, 1965.0,1970.5, 1971.0,1971.5, 
            1972.0,1973.5, 1974.0,1974.5, 1975.0,1975.5, 1976.0,1983.5, 1984.0,
            1984.5, 1985.0,1988.5, 1989.0,1995.5, 1996.0,1998.5, 1999.0,1999.5, 
            2000.0,2000.5, 2001.0,2005.5, 2006.0,2007.5, 2008.0,2008.5, 2009.0,
            2010.5, 2011.0,2011.5, 2012.0,2016.5, 2017.0,2017.5, 2018.0,2020.5, 
            2021.0,2021.5, 2022.0,2022.5]
    date=yermon(dat)
    if date in elyear:
        return 'el'
    elif date in layear:
        return 'la'
    else:
        return 'an'

# %%
times[(np.array(list(map(yearis,times)))=='la')&(times.month==7)]
# Out:
# DatetimeIndex(['1995-07-01', '1995-07-02', '1995-07-03', '1995-07-04',
#                '1995-07-05', '1995-07-06', '1995-07-07', '1995-07-08',
#                '1995-07-09', '1995-07-10',
#                ...
#                '2022-07-22', '2022-07-23', '2022-07-24', '2022-07-25',
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#                '2022-07-30', '2022-07-31'],
#               dtype='datetime64[ns]', length=434, freq=None)

# %%
mltt_la_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==7)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='la')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_la_7']
                       )
mltt_la_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==8)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='la')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_la_8']
                       )
mltt_la_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==9)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='la')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_la_9']
                       )
mltt_el_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==7)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='el')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_el_7']
                       )
mltt_el_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==8)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='el')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_el_8']
                       )
mltt_el_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==9)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='el')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_el_9']
                       )
mltt_an_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==7)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='an')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_an_7']
                       )
mltt_an_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==8)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='an')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_an_8']
                       )
mltt_an_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==9)],
    data=np.nanmean(mltt[(np.array(list(map(yearis,times)))=='an')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['mltt_an_9']
                       )

# %%
hadv_la_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==7)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='la')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_la_7']
                       )
hadv_la_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==8)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='la')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_la_8']
                       )
hadv_la_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==9)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='la')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_la_9']
                       )
hadv_el_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==7)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='el')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_el_7']
                       )
hadv_el_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==8)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='el')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_el_8']
                       )
hadv_el_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==9)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='el')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_el_9']
                       )
hadv_an_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==7)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='an')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_an_7']
                       )
hadv_an_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==8)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='an')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_an_8']
                       )
hadv_an_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==9)],
    data=np.nanmean(hadv[(np.array(list(map(yearis,times)))=='an')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['hadv_an_9']
                       )

# %%
Q_la_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==7)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='la')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_la_7']
                       )
Q_la_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==8)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='la')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_la_8']
                       )
Q_la_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='la')&(times.month==9)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='la')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_la_9']
                       )
Q_el_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==7)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='el')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_el_7']
                       )
Q_el_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==8)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='el')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_el_8']
                       )
Q_el_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='el')&(times.month==9)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='el')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_el_9']
                       )
Q_an_7=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==7)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='an')&(times.month==7),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_an_7']
                       )
Q_an_8=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==8)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='an')&(times.month==8),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_an_8']
                       )
Q_an_9=pd.DataFrame(
    index=times[(np.array(list(map(yearis,times)))=='an')&(times.month==9)],
    data=np.nanmean(Q[(np.array(list(map(yearis,times)))=='an')&(times.month==9),:,:][:,latind,:][:,:,lonind],axis=(1,2)),
    columns=['Q_an_9']
                       )

# %%
mltt_la_7.to_csv('mltt_la_7.csv')
mltt_la_8.to_csv('mltt_la_8.csv')
mltt_la_9.to_csv('mltt_la_9.csv')
mltt_el_7.to_csv('mltt_el_7.csv')
mltt_el_8.to_csv('mltt_el_8.csv')
mltt_el_9.to_csv('mltt_el_9.csv')
mltt_an_7.to_csv('mltt_an_7.csv')
mltt_an_8.to_csv('mltt_an_8.csv')
mltt_an_9.to_csv('mltt_an_9.csv')
hadv_la_7.to_csv('hadv_la_7.csv')
hadv_la_8.to_csv('hadv_la_8.csv')
hadv_la_9.to_csv('hadv_la_9.csv')
hadv_el_7.to_csv('hadv_el_7.csv')
hadv_el_8.to_csv('hadv_el_8.csv')
hadv_el_9.to_csv('hadv_el_9.csv')
hadv_an_7.to_csv('hadv_an_7.csv')
hadv_an_8.to_csv('hadv_an_8.csv')
hadv_an_9.to_csv('hadv_an_9.csv')
Q_la_7.to_csv('Q_la_7.csv')
Q_la_8.to_csv('Q_la_8.csv')
Q_la_9.to_csv('Q_la_9.csv')
Q_el_7.to_csv('Q_el_7.csv')
Q_el_8.to_csv('Q_el_8.csv')
Q_el_9.to_csv('Q_el_9.csv')
Q_an_7.to_csv('Q_an_7.csv')
Q_an_8.to_csv('Q_an_8.csv')
Q_an_9.to_csv('Q_an_9.csv')

# %%
Q_la_7.to_csv('Q_la_7.csv')
Q_la_8.to_csv('Q_la_8.csv')
Q_la_9.to_csv('Q_la_9.csv')
Q_el_7.to_csv('Q_el_7.csv')
Q_el_8.to_csv('Q_el_8.csv')
Q_el_9.to_csv('Q_el_9.csv')
Q_an_7.to_csv('Q_an_7.csv')
Q_an_8.to_csv('Q_an_8.csv')
Q_an_9.to_csv('Q_an_9.csv')
